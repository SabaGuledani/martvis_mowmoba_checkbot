# %%
while True:
    
    import requests
    TOKEN = "bot token here"
    chat_id = "chat id here"
    message = "your message"
    url = f"https://api.telegram.org/bot{TOKEN}/sendMessage?chat_id={chat_id}&text={message}"

    from selenium  import webdriver as wd
    import chromedriver_binary
    from selenium.webdriver.common.keys import Keys

    import time
    
    wd = wd.Chrome()
    wd.implicitly_wait(10)
    wd.get("https://my.sa.gov.ge/drivinglicenses/practicalexam")

    time.sleep(7)

    scroll_inside = wd.find_element_by_xpath('/html/body/div/div[2]/div/mat-dialog-container/app-practical-aggrements/div/div[2]')
    wd.execute_script("arguments[0].scroll(0, arguments[0].scrollHeight);", scroll_inside)

    time.sleep(3)

    dialog = wd.find_element_by_xpath('//*[@id="mat-dialog-0"]')
    dialog.send_keys(Keys.END)

    time.sleep(2)

    button_vetanxmebi = wd.find_element_by_xpath('//*[@id="mat-dialog-0"]/app-practical-aggrements/div/div[3]/button')
    button_vetanxmebi.click()

    time.sleep(2)

    id_input = wd.find_element_by_xpath('//*[@id="mat-input-0"]')
    id_input.send_keys('your ID')

    time.sleep(2)

    button_search = wd.find_element_by_xpath('/html/body/app-root/div/app-public-open-reg/div/div[1]/div[2]/div/div/div/div/div/img')
    button_search.click()

    time.sleep(10)

    span = wd.find_element_by_xpath('/html/body/app-root/div/app-public-open-reg/div/div[1]/div[2]/div/div/div/div/div[3]/mat-form-field/div/div[1]/div[3]')
    span.click()

    time.sleep(3)

    b = wd.find_element_by_xpath('//*[@id="mat-option-1"]/span')
    b.click()

    time.sleep(3)

    span2 = wd.find_element_by_xpath('/html/body/app-root/div/app-public-open-reg/div/div[1]/div[2]/div/div/div/div/div[4]/mat-form-field/div/div[1]/div[3]')
    span2.click()

    time.sleep(3)

    sachxere = wd.find_element_by_xpath('//*[@id="mat-option-11"]/span')
    sachxere.click()

    time.sleep(3)

    tarigi = wd.find_element_by_xpath('/html/body/app-root/div/app-public-open-reg/div/div[1]/div[2]/div/div/div/div/div[5]/mat-form-field/div/div[1]/div[3]')
    tarigi.click()
    
    time.sleep(1.5)
    for elem in wd.find_elements_by_xpath('//*[@id="mat-select-4-panel"]'):
        a = elem.text
    
    url2 = f"https://api.telegram.org/bot{TOKEN}/sendMessage?chat_id={chat_id}&text={a}"
    print(requests.get(url2).json())
    
    time.sleep(1.5)
    if len(a.split())>2:
        print(requests.get(url).json())

    time.sleep(1.5)
    
    wd.close()
    
    time.sleep(20)
